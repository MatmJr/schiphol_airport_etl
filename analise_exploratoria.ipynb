# %%
import pandas as pd

df = pd.read_csv('flights.csv')

# %%
df
# Out:
#                       lastUpdatedAt              actualLandingTime  \
# 0     2025-07-30T03:13:09.080+02:00  2025-07-30T01:06:37.000+02:00
# 1     2025-07-30T01:44:21.092+02:00  2025-07-30T00:05:12.000+02:00
# 2     2025-07-30T03:13:09.080+02:00  2025-07-30T01:06:37.000+02:00
# 3     2025-07-30T01:44:21.092+02:00  2025-07-30T00:05:12.000+02:00
# 4     2025-07-30T01:22:04.089+02:00  2025-07-29T23:55:21.000+02:00
# ...                             ...                            ...
# 4849  2025-07-29T14:44:29.688+02:00                            NaN
# 4850  2025-07-29T14:44:29.688+02:00                            NaN
# 4851  2025-07-29T20:36:25.983+02:00                            NaN
# 4852  2025-07-29T18:06:23.764+02:00                            NaN
# 4853  2025-07-29T11:51:32.718+02:00                            NaN
#
#                                aircraftType      baggageClaim  \
# 0     {'iataMain': '32S', 'iataSub': '32Q'}  {'belts': ['4']}
# 1     {'iataMain': '32S', 'iataSub': '32Q'}  {'belts': ['2']}
# 2     {'iataMain': '32S', 'iataSub': '32Q'}  {'belts': ['4']}
# 3     {'iataMain': '32S', 'iataSub': '32Q'}  {'belts': ['2']}
# 4     {'iataMain': '737', 'iataSub': '73H'}  {'belts': ['4']}
# ...                                     ...               ...
# 4849  {'iataMain': 'EMJ', 'iataSub': 'E90'}               NaN
# 4850  {'iataMain': 'EMJ', 'iataSub': 'E90'}               NaN
# 4851  {'iataMain': '737', 'iataSub': '73H'}               NaN
# 4852  {'iataMain': '74F', 'iataSub': '74Y'}               NaN
# 4853  {'iataMain': '32S', 'iataSub': '32Q'}               NaN
#
#                       codeshares           estimatedLandingTime  \
# 0     {'codeshares': ['KL2568']}  2025-07-30T01:06:37.000+02:00
# 1     {'codeshares': ['KL3282']}  2025-07-30T00:05:12.000+02:00
# 2     {'codeshares': ['KL2568']}  2025-07-30T01:06:37.000+02:00
# 3     {'codeshares': ['KL3282']}  2025-07-30T00:05:12.000+02:00
# 4     {'codeshares': ['KL2751']}  2025-07-29T23:55:21.000+02:00
# ...                          ...                            ...
# 4849  {'codeshares': ['G35521']}  2025-07-30T23:32:00.000+02:00
# 4850  {'codeshares': ['G35521']}  2025-07-30T23:32:00.000+02:00
# 4851                         NaN  2025-07-30T23:37:00.000+02:00
# 4852                         NaN                            NaN
# 4853                         NaN  2025-07-30T23:42:00.000+02:00
#
#                  expectedTimeOnBelt flightDirection flightName  flightNumber  \
# 0     2025-07-30T02:13:09.000+02:00               A     HV5218          5218
# 1     2025-07-30T00:38:38.000+02:00               A     HV5352          5352
# 2     2025-07-30T02:13:09.000+02:00               A     KL2568          2568
# 3     2025-07-30T00:38:38.000+02:00               A     KL3282          3282
# 4     2025-07-30T00:20:01.000+02:00               A     HV5462          5462
# ...                             ...             ...        ...           ...
# 4849                            NaN               A     G35521          5521
# 4850                            NaN               A     KL1568          1568
# 4851                            NaN               A     HV5136          5136
# 4852                            NaN               D     MP6121          6121
# 4853                            NaN               A     HV5518          5518
#
#       ...  aircraftRegistration  checkinAllocations expectedSecurityFilter  \
# 0     ...                   NaN                 NaN                    NaN
# 1     ...                   NaN                 NaN                    NaN
# 2     ...                   NaN                 NaN                    NaN
# 3     ...                   NaN                 NaN                    NaN
# 4     ...                   NaN                 NaN                    NaN
# ...   ...                   ...                 ...                    ...
# 4849  ...                   NaN                 NaN                    NaN
# 4850  ...                   NaN                 NaN                    NaN
# 4851  ...                   NaN                 NaN                    NaN
# 4852  ...                 PHCKB                 NaN                    NaN
# 4853  ...                   NaN                 NaN                    NaN
#
#      gate pier  publicEstimatedOffBlockTime expectedTimeBoarding  \
# 0     NaN  NaN                          NaN                  NaN
# 1     NaN  NaN                          NaN                  NaN
# 2     NaN  NaN                          NaN                  NaN
# 3     NaN  NaN                          NaN                  NaN
# 4     NaN  NaN                          NaN                  NaN
# ...   ...  ...                          ...                  ...
# 4849  NaN  NaN                          NaN                  NaN
# 4850  NaN  NaN                          NaN                  NaN
# 4851  NaN  NaN                          NaN                  NaN
# 4852  NaN  NaN                          NaN                  NaN
# 4853  NaN  NaN                          NaN                  NaN
#
#      expectedTimeGateClosing expectedTimeGateOpen transferPositions
# 0                        NaN                  NaN               NaN
# 1                        NaN                  NaN               NaN
# 2                        NaN                  NaN               NaN
# 3                        NaN                  NaN               NaN
# 4                        NaN                  NaN               NaN
# ...                      ...                  ...               ...
# 4849                     NaN                  NaN               NaN
# 4850                     NaN                  NaN               NaN
# 4851                     NaN                  NaN               NaN
# 4852                     NaN                  NaN               NaN
# 4853                     NaN                  NaN               NaN
#
# [4854 rows x 35 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Listar Colunas:

# %%
df.columns
# Out:
# Index(['lastUpdatedAt', 'actualLandingTime', 'aircraftType', 'baggageClaim',
#        'codeshares', 'estimatedLandingTime', 'expectedTimeOnBelt',
#        'flightDirection', 'flightName', 'flightNumber', 'id',
#        'isOperationalFlight', 'mainFlight', 'prefixIATA', 'prefixICAO',
#        'airlineCode', 'publicFlightState', 'route', 'scheduleDateTime',
#        'scheduleDate', 'scheduleTime', 'serviceType', 'terminal',
#        'schemaVersion', 'actualOffBlockTime', 'aircraftRegistration',
#        'checkinAllocations', 'expectedSecurityFilter', 'gate', 'pier',
#        'publicEstimatedOffBlockTime', 'expectedTimeBoarding',
#        'expectedTimeGateClosing', 'expectedTimeGateOpen', 'transferPositions'],
#       dtype='object')

# %% [markdown]
# Descrição numerica do dataframe

# %%
df.describe()
# Out:
#        flightNumber            id  airlineCode     terminal  schemaVersion
# count   4854.000000  4.854000e+03  4850.000000  2553.000000         4854.0
# mean    5074.754841  1.428877e+17   658.028454     1.515472            4.0
# std     3292.446986  3.658901e+09  1318.127110     0.725066            0.0
# min        1.000000  1.428877e+17    12.000000     1.000000            4.0
# 25%     1622.250000  1.428877e+17    80.000000     1.000000            4.0
# 50%     5673.000000  1.428877e+17   100.000000     1.000000            4.0
# 75%     8235.750000  1.428877e+17   289.000000     2.000000            4.0
# max     9993.000000  1.428877e+17  5326.000000     4.000000            4.0

# %% [markdown]
# Descrição dos valores não numéricos (Categóricas)

# %%
df.describe(include='O')
# Out:
#                         lastUpdatedAt              actualLandingTime  \
# count                            4854                             52
# unique                           1446                             33
# top     2025-07-29T17:30:18.548+02:00  2025-07-30T05:14:13.000+02:00
# freq                               13                              4
#
#                                  aircraftType       baggageClaim  \
# count                                    4854                181
# unique                                     41                 15
# top     {'iataMain': '737', 'iataSub': '73H'}  {'belts': ['15']}
# freq                                      988                 29
#
#                                                codeshares  \
# count                                                4384
# unique                                                976
# top     {'codeshares': ['AM6354', 'AZ3805', 'CZ7750', ...
# freq                                                   13
#
#                  estimatedLandingTime             expectedTimeOnBelt  \
# count                            2397                             49
# unique                            323                             30
# top     2025-07-30T15:47:00.000+02:00  2025-07-30T05:49:55.835+02:00
# freq                               45                              4
#
#        flightDirection flightName mainFlight  ... aircraftRegistration  \
# count             4854       4854       4854  ...                 2329
# unique               2       4843       1438  ...                  403
# top                  A     DL9318     KL1220  ...                PHAXF
# freq              2430          2         13  ...                   32
#
#                                        checkinAllocations  \
# count                                                2372
# unique                                                494
# top     {'checkinAllocations': [{'endTime': '2025-07-3...
# freq                                                   38
#
#        expectedSecurityFilter  gate  pier    publicEstimatedOffBlockTime  \
# count                    1851  2348  2370                             13
# unique                      5   121     8                              8
# top                       VF1    D6     D  2025-07-30T07:00:00.000+02:00
# freq                     1470   238   863                              3
#
#                  expectedTimeBoarding        expectedTimeGateClosing  \
# count                            1864                           1892
# unique                            160                            154
# top     2025-07-30T09:10:00.000+02:00  2025-07-30T20:20:00.000+02:00
# freq                               38                             58
#
#                  expectedTimeGateOpen           transferPositions
# count                            1880                         126
# unique                            151                           3
# top     2025-07-30T20:05:00.000+02:00  {'transferPositions': [3]}
# freq                               47                          62
#
# [4 rows x 29 columns]

# %% [markdown]
# Obter mais informações:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4854 entries, 0 to 4853
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   lastUpdatedAt                4854 non-null   object
#  1   actualLandingTime            52 non-null     object
#  2   aircraftType                 4854 non-null   object
#  3   baggageClaim                 181 non-null    object
#  4   codeshares                   4384 non-null   object
#  5   estimatedLandingTime         2397 non-null   object
#  6   expectedTimeOnBelt           49 non-null     object
#  7   flightDirection              4854 non-null   object
#  8   flightName                   4854 non-null   object
#  9   flightNumber                 4854 non-null   int64
#  10  id                           4854 non-null   int64
#  11  isOperationalFlight          4854 non-null   bool
#  12  mainFlight                   4854 non-null   object
#  13  prefixIATA                   4852 non-null   object
#  14  prefixICAO                   4830 non-null   object
#  15  airlineCode                  4850 non-null   float64
#  16  publicFlightState            4854 non-null   object
#  17  route                        4854 non-null   object
#  18  scheduleDateTime             4854 non-null   object
#  19  scheduleDate                 4854 non-null   object
#  20  scheduleTime                 4854 non-null   object
#  21  serviceType                  4854 non-null   object
#  22  terminal                     2553 non-null   float64
#  23  schemaVersion                4854 non-null   int64
#  24  actualOffBlockTime           7 non-null      object
#  25  aircraftRegistration         2329 non-null   object
#  26  checkinAllocations           2372 non-null   object
#  27  expectedSecurityFilter       1851 non-null   object
#  28  gate                         2348 non-null   object
#  29  pier                         2370 non-null   object
#  30  publicEstimatedOffBlockTime  13 non-null     object
#  31  expectedTimeBoarding         1864 non-null   object
#  32  expectedTimeGateClosing      1892 non-null   object
#  33  expectedTimeGateOpen         1880 non-null   object
#  34  transferPositions            126 non-null    object
# dtypes: bool(1), float64(2), int64(3), object(29)
# memory usage: 1.3+ MB

# %% [markdown]
# Vamos estudar os modelos de avião que mais aparecem e as rotas mais fequentes

# %%
df.at[0, 'aircraftType']
# Out:
# "{'iataMain': '32S', 'iataSub': '32Q'}"

# %%
df["aircraftType"][1000]
# Out:
# "{'iataMain': '32S', 'iataSub': '319'}"

# %% [markdown]
# Vamos utilizar unma biblioteca que converte strings em dicionários

# %%
import ast

teste = ast.literal_eval(df["aircraftType"][0])
teste
# Out:
# {'iataMain': '32S', 'iataSub': '32Q'}

# %% [markdown]
# Uma forma de conververter todos os valores que estão na coluna "aircraftType"

# %%
for i in range(len(df)):
    df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# ...
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])
# C:\Users\marco\AppData\Local\Temp\ipykernel_8448\822957797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aircraftType"][i] = ast.literal_eval(df["aircraftType"][i])

# %%
df["aircraftType"][0]['iataMain']
# Out:
# '32S'

# %%
df["modeloAviao"] = None

# %%
# O valor que você quer atribuir
valor_a_atribuir = df["aircraftType"][0]['iataMain']

# Atribuição usando .loc[linha, coluna]
df.loc[0, "modeloAviao"] = valor_a_atribuir

# %%
df
# Out:
#                       lastUpdatedAt              actualLandingTime  \
# 0     2025-07-30T03:13:09.080+02:00  2025-07-30T01:06:37.000+02:00
# 1     2025-07-30T01:44:21.092+02:00  2025-07-30T00:05:12.000+02:00
# 2     2025-07-30T03:13:09.080+02:00  2025-07-30T01:06:37.000+02:00
# 3     2025-07-30T01:44:21.092+02:00  2025-07-30T00:05:12.000+02:00
# 4     2025-07-30T01:22:04.089+02:00  2025-07-29T23:55:21.000+02:00
# ...                             ...                            ...
# 4849  2025-07-29T14:44:29.688+02:00                            NaN
# 4850  2025-07-29T14:44:29.688+02:00                            NaN
# 4851  2025-07-29T20:36:25.983+02:00                            NaN
# 4852  2025-07-29T18:06:23.764+02:00                            NaN
# 4853  2025-07-29T11:51:32.718+02:00                            NaN
#
#                                aircraftType      baggageClaim  \
# 0     {'iataMain': '32S', 'iataSub': '32Q'}  {'belts': ['4']}
# 1     {'iataMain': '32S', 'iataSub': '32Q'}  {'belts': ['2']}
# 2     {'iataMain': '32S', 'iataSub': '32Q'}  {'belts': ['4']}
# 3     {'iataMain': '32S', 'iataSub': '32Q'}  {'belts': ['2']}
# 4     {'iataMain': '737', 'iataSub': '73H'}  {'belts': ['4']}
# ...                                     ...               ...
# 4849  {'iataMain': 'EMJ', 'iataSub': 'E90'}               NaN
# 4850  {'iataMain': 'EMJ', 'iataSub': 'E90'}               NaN
# 4851  {'iataMain': '737', 'iataSub': '73H'}               NaN
# 4852  {'iataMain': '74F', 'iataSub': '74Y'}               NaN
# 4853  {'iataMain': '32S', 'iataSub': '32Q'}               NaN
#
#                       codeshares           estimatedLandingTime  \
# 0     {'codeshares': ['KL2568']}  2025-07-30T01:06:37.000+02:00
# 1     {'codeshares': ['KL3282']}  2025-07-30T00:05:12.000+02:00
# 2     {'codeshares': ['KL2568']}  2025-07-30T01:06:37.000+02:00
# 3     {'codeshares': ['KL3282']}  2025-07-30T00:05:12.000+02:00
# 4     {'codeshares': ['KL2751']}  2025-07-29T23:55:21.000+02:00
# ...                          ...                            ...
# 4849  {'codeshares': ['G35521']}  2025-07-30T23:32:00.000+02:00
# 4850  {'codeshares': ['G35521']}  2025-07-30T23:32:00.000+02:00
# 4851                         NaN  2025-07-30T23:37:00.000+02:00
# 4852                         NaN                            NaN
# 4853                         NaN  2025-07-30T23:42:00.000+02:00
#
#                  expectedTimeOnBelt flightDirection flightName  flightNumber  \
# 0     2025-07-30T02:13:09.000+02:00               A     HV5218          5218
# 1     2025-07-30T00:38:38.000+02:00               A     HV5352          5352
# 2     2025-07-30T02:13:09.000+02:00               A     KL2568          2568
# 3     2025-07-30T00:38:38.000+02:00               A     KL3282          3282
# 4     2025-07-30T00:20:01.000+02:00               A     HV5462          5462
# ...                             ...             ...        ...           ...
# 4849                            NaN               A     G35521          5521
# 4850                            NaN               A     KL1568          1568
# 4851                            NaN               A     HV5136          5136
# 4852                            NaN               D     MP6121          6121
# 4853                            NaN               A     HV5518          5518
#
#       ...  checkinAllocations  expectedSecurityFilter gate pier  \
# 0     ...                 NaN                     NaN  NaN  NaN
# 1     ...                 NaN                     NaN  NaN  NaN
# 2     ...                 NaN                     NaN  NaN  NaN
# 3     ...                 NaN                     NaN  NaN  NaN
# 4     ...                 NaN                     NaN  NaN  NaN
# ...   ...                 ...                     ...  ...  ...
# 4849  ...                 NaN                     NaN  NaN  NaN
# 4850  ...                 NaN                     NaN  NaN  NaN
# 4851  ...                 NaN                     NaN  NaN  NaN
# 4852  ...                 NaN                     NaN  NaN  NaN
# 4853  ...                 NaN                     NaN  NaN  NaN
#
#      publicEstimatedOffBlockTime  expectedTimeBoarding  \
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# ...                          ...                   ...
# 4849                         NaN                   NaN
# 4850                         NaN                   NaN
# 4851                         NaN                   NaN
# 4852                         NaN                   NaN
# 4853                         NaN                   NaN
#
#      expectedTimeGateClosing expectedTimeGateOpen transferPositions  \
# 0                        NaN                  NaN               NaN
# 1                        NaN                  NaN               NaN
# 2                        NaN                  NaN               NaN
# 3                        NaN                  NaN               NaN
# 4                        NaN                  NaN               NaN
# ...                      ...                  ...               ...
# 4849                     NaN                  NaN               NaN
# 4850                     NaN                  NaN               NaN
# 4851                     NaN                  NaN               NaN
# 4852                     NaN                  NaN               NaN
# 4853                     NaN                  NaN               NaN
#
#      modeloAviao
# 0            32S
# 1           None
# 2           None
# 3           None
# 4           None
# ...          ...
# 4849        None
# 4850        None
# 4851        None
# 4852        None
# 4853        None
#
# [4854 rows x 36 columns]
